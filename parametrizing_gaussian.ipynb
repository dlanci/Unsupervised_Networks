# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal as mvn

# %%
def softplus(x):
    return np.log1p(np.exp(x))

# %%
W1 = np.random.randn(4,3)
W2 = np.random.randn(3,2*2)

# %%
def forward(x, W1, W2):
    hidden = np.tanh(x.dot(W1))
    output = hidden.dot(W2)
    
    mean = output[:2]
    stddev = softplus(output[2:])
    
    return mean, stddev

# %%
x = np.random.randn(4)

# %%
x
# Out:
# array([ 1.54998675, -1.57297776, -0.97082871,  0.59803575])

# %%
mean, stddev = forward(x, W1, W2)
print('mean:', mean)
print('stddev:', stddev)
# Out:
# mean: [-0.25015825  0.63709511]
# stddev: [ 1.40649177  0.38944228]

# %%
samples = mvn.rvs(mean=mean, cov=stddev**2, size = 10000)

# %%
plt.scatter(samples[:,0],samples[:,1], alpha=0.5)
plt.show()
